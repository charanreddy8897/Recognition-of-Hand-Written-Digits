# %%
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score  
from IPython.display import Image  
from sklearn.tree import export_graphviz

# %%
df = pd.read_csv(r"c:/Users/Ub Student/Documents/digits_dataset.csv",header = None)

# %%
X = df.drop(columns = 64)
y = df[64]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.30, random_state= 355)

# %%
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LogisticRegression
log_reg = LogisticRegression()

log_reg.fit(x_train,y_train)
# Out:
# C:\Users\UB Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9620403321470937

# %%
rand_clf = RandomForestClassifier(random_state=6)

# %%
rand_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=6)

# %%
rand_clf.score(x_test,y_test)
# Out:
# 0.9774614472123369

# %%
grid_param = {
    "n_estimators" : [90,100,115,130],
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
grid_search = GridSearchCV(estimator=rand_clf,param_grid=grid_param,cv=3,n_jobs =-1,verbose = 3)

# %%
grid_search.fit(x_train,y_train)

# %%
grid_search.best_params_

# %%
rand_clf = RandomForestClassifier(criterion= 'entropy',
 max_depth = 12,
 max_features = 'log2',
 min_samples_leaf = 1,
 min_samples_split= 5,
 n_estimators = 90,random_state=6)

# %%
rand_clf.fit(x_train,y_train)

# %%
rand_clf.score(x_test,y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_train,y_train)
# Out:
# 0.9903406202338587

# %%
knn.score(x_test,y_test)
# Out:
# 0.9833926453143536

# %%
param_grid = { 'algorithm' : ['ball_tree', 'kd_tree', 'brute'],
               'leaf_size' : [18,20,25,27,30,32,34],
               'n_neighbors' : [3,5,7,9,10,11,12,13]
              }

# %%
gridsearch = GridSearchCV(knn, param_grid,verbose=3)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.989, total=   0.5s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.987, total=   0.5s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.982, total=   0.6s
# [CV] algorithm=ball_tree, leaf_size=18, n_neighbors=3 ................
# [CV]  algorithm=ball_tree, leaf_size=18, n_neighbors=3, score=0.989, total=   0.6s
# ...

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 18, 'n_neighbors': 5}

# %%
knn = KNeighborsClassifier(algorithm = 'ball_tree', leaf_size =18, n_neighbors =5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=18)

# %%
knn.score(x_train,y_train)
# Out:
# 0.9905948144382308

# %%
knn.score(x_test,y_test)
# Out:
# 0.9833926453143536

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7882562277580071

# %%
import numpy as np
pca_train = PCA(n_components=20).fit(X)

# %%
data = pca_train.transform(X)

# %%
data.shape
# Out:
# (5620, 20)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(data,y,test_size = 0.30, random_state= 355)

# %%
log_reg.fit(X_train,Y_train)
# Out:
# C:\Users\UB Student\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred = log_reg.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9620403321470937

# %%
rand_clf_pca = RandomForestClassifier(random_state=6)
rand_clf_pca.fit(X_train,Y_train)
rand_clf_pca.score(X_test,Y_test)
# Out:
# 0.9727164887307236

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=18)

# %%
knn.score(X_train,Y_train)
# Out:
# 0.9888154550076258

# %%
model.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
y_pred_pca = model.predict(X_test)
print(accuracy_score(Y_test, y_pred_pca))
# Out:
# 0.9424673784104389
